# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From D:\Anacondas\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Create a simple ANN model
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(10,)),  # Adjust input shape based on your features
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Assuming binary classification, adjust as needed
])

plt.figure(figsize=(6,3))
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Simulate streaming data
streaming_data = np.random.rand(10, 10)  # 10 features, 10 data points

# Lists to store performance metrics for plotting
epochs_list = []
accuracy_list = []

# Continuous learning loop
for epoch in range(50):  # Update the number of epochs as needed
    # Simulate receiving new data
    new_data_point = np.random.rand(10)

    # Add the new data point to the training set
    X = np.vstack([streaming_data, new_data_point])
    y = np.random.randint(0, 2, size=(11,))  # Random binary labels for example

    # Train the model on the updated dataset
    history = model.fit(X, y, epochs=1, verbose=0)  # Update epochs as needed

    # Update the streaming data for the next iteration
    streaming_data = np.vstack([streaming_data[1:], new_data_point])

    # Record performance metrics
    epochs_list.append(epoch + 1)
    accuracy_list.append(history.history['accuracy'][0])

    # Print real-time prediction
    real_time_prediction = model.predict(np.expand_dims(new_data_point, axis=0))
    print(f"Epoch {epoch + 1}, Real-time Prediction: {real_time_prediction[0, 0]:.4f}")

# Plot performance metrics
plt.plot(epochs_list, accuracy_list, label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Real-Time Learning Performance')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Epoch 1, Real-time Prediction: 0.3633
# 1/1 [==============================] - 0s 16ms/step
# Epoch 2, Real-time Prediction: 0.3174
# 1/1 [==============================] - 0s 21ms/step
# Epoch 3, Real-time Prediction: 0.3286
# 1/1 [==============================] - 0s 19ms/step
# Epoch 4, Real-time Prediction: 0.3702
# 1/1 [==============================] - 0s 24ms/step
# Epoch 5, Real-time Prediction: 0.3345
# 1/1 [==============================] - 0s 18ms/step
# Epoch 6, Real-time Prediction: 0.3778
# 1/1 [==============================] - 0s 28ms/step
# Epoch 7, Real-time Prediction: 0.3947
# 1/1 [==============================] - 0s 28ms/step
# Epoch 8, Real-time Prediction: 0.3277
# 1/1 [==============================] - 0s 31ms/step
# Epoch 9, Real-time Prediction: 0.3216
# 1/1 [==============================] - 0s 31ms/step
# Epoch 10, Real-time Prediction: 0.3977
# 1/1 [==============================] - 0s 9ms/step
# Epoch 11, Real-time Prediction: 0.3476
# 1/1 [==============================] - 0s 21ms/step
# Epoch 12, Real-time Prediction: 0.4063
# 1/1 [==============================] - 0s 20ms/step
# Epoch 13, Real-time Prediction: 0.4056
# 1/1 [==============================] - 0s 23ms/step
# Epoch 14, Real-time Prediction: 0.4190
# 1/1 [==============================] - 0s 33ms/step
# Epoch 15, Real-time Prediction: 0.4181
# 1/1 [==============================] - 0s 27ms/step
# Epoch 16, Real-time Prediction: 0.4525
# 1/1 [==============================] - 0s 24ms/step
# Epoch 17, Real-time Prediction: 0.4183
# 1/1 [==============================] - 0s 27ms/step
# Epoch 18, Real-time Prediction: 0.4278
# 1/1 [==============================] - 0s 16ms/step
# Epoch 19, Real-time Prediction: 0.4444
# 1/1 [==============================] - 0s 6ms/step
# Epoch 20, Real-time Prediction: 0.4785
# 1/1 [==============================] - 0s 16ms/step
# Epoch 21, Real-time Prediction: 0.4876
# 1/1 [==============================] - 0s 12ms/step
# Epoch 22, Real-time Prediction: 0.4687
# 1/1 [==============================] - 0s 33ms/step
# Epoch 23, Real-time Prediction: 0.4959
# 1/1 [==============================] - 0s 8ms/step
# Epoch 24, Real-time Prediction: 0.5044
# 1/1 [==============================] - 0s 17ms/step
# Epoch 25, Real-time Prediction: 0.5015
# 1/1 [==============================] - 0s 33ms/step
# Epoch 26, Real-time Prediction: 0.4986
# 1/1 [==============================] - 0s 29ms/step
# Epoch 27, Real-time Prediction: 0.4959
# 1/1 [==============================] - 0s 31ms/step
# Epoch 28, Real-time Prediction: 0.5103
# 1/1 [==============================] - 0s 16ms/step
# Epoch 29, Real-time Prediction: 0.5044
# 1/1 [==============================] - 0s 21ms/step
# Epoch 30, Real-time Prediction: 0.5315
# 1/1 [==============================] - 0s 16ms/step
# Epoch 31, Real-time Prediction: 0.5379
# 1/1 [==============================] - 0s 19ms/step
# Epoch 32, Real-time Prediction: 0.5173
# 1/1 [==============================] - 0s 10ms/step
# Epoch 33, Real-time Prediction: 0.5427
# 1/1 [==============================] - 0s 16ms/step
# Epoch 34, Real-time Prediction: 0.5268
# 1/1 [==============================] - 0s 31ms/step
# Epoch 35, Real-time Prediction: 0.5357
# 1/1 [==============================] - 0s 16ms/step
# Epoch 36, Real-time Prediction: 0.5396
# 1/1 [==============================] - 0s 16ms/step
# Epoch 37, Real-time Prediction: 0.5553
# 1/1 [==============================] - 0s 16ms/step
# Epoch 38, Real-time Prediction: 0.5393
# 1/1 [==============================] - 0s 24ms/step
# Epoch 39, Real-time Prediction: 0.5220
# 1/1 [==============================] - 0s 16ms/step
# Epoch 40, Real-time Prediction: 0.5153
# 1/1 [==============================] - 0s 16ms/step
# Epoch 41, Real-time Prediction: 0.5498
# 1/1 [==============================] - 0s 16ms/step
# Epoch 42, Real-time Prediction: 0.5408
# 1/1 [==============================] - 0s 17ms/step
# Epoch 43, Real-time Prediction: 0.5336
# 1/1 [==============================] - 0s 33ms/step
# Epoch 44, Real-time Prediction: 0.5415
# 1/1 [==============================] - 0s 24ms/step
# Epoch 45, Real-time Prediction: 0.5428
# 1/1 [==============================] - 0s 21ms/step
# Epoch 46, Real-time Prediction: 0.5210
# 1/1 [==============================] - 0s 30ms/step
# Epoch 47, Real-time Prediction: 0.5204
# 1/1 [==============================] - 0s 33ms/step
# Epoch 48, Real-time Prediction: 0.5268
# 1/1 [==============================] - 0s 16ms/step
# Epoch 49, Real-time Prediction: 0.5358
# 1/1 [==============================] - 0s 16ms/step
# Epoch 50, Real-time Prediction: 0.5396
